# %%
import h5py 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
rawdata = np.loadtxt('../data/rawdata_decoupled_phasediag.dat')
fillings= np.unique(rawdata[:,4])
criData = []
for fill in fillings:
        print (fill)
        atFill = rawdata[np.where(rawdata[:,4]==fill)]
        lmin = np.argmin(atFill[:,0])
        print (lmin)
        criData.append(atFill[lmin])
criData = np.array(criData)
print (criData.shape)
print (criData[:,0])
print (criData[:,4])
print(criData[:,11])
# Out:
# 0.80001319
# 0
# 0.82001523
# 0
# 0.83998815
# 0
# 0.86001083
# 0
# 0.88001127
# 0
# (5, 16)
# [  6.14000000e-06   6.14000000e-06   1.70001830e-01   2.76308690e-01
#    3.27024920e-01]
# [ 0.80001319  0.82001523  0.83998815  0.86001083  0.88001127]
# [ 0.66022061  2.39109115  1.67497616  0.74157125  0.63637691]

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax2=plt.twinx()
rawdata = np.loadtxt("../data/rawdata_phasediag.dat")
ln1=ax.plot(1-rawdata[:,4],rawdata[:,0],'-',label=r"$\Lambda_{cri}$")
ax.fill_between(1-rawdata[:,4],rawdata[:,0],alpha=0.2)
ax.scatter(1-rawdata[:,4],rawdata[:,0],color="steelblue",alpha=0.7,edgecolor="black",s=70)
ax.scatter(1-criData[:,4],criData[:,0],color="orange",alpha=0.7,edgecolor="black",s=70)
ax.plot(1-criData[:,4],criData[:,0],'-',label=r"$\Lambda_{cri}$ decoup")
ax.fill_between(1-criData[:,4],criData[:,0],alpha=0.2)
ax.set_ylim([0,0.45])
ln2=ax2.plot(1-rawdata[:,4],4*rawdata[:,11],"-",color="green",linestyle="dashed",label=r"$\mathcal{D}^{\mathbf{Q}=\mathbf{0},\Omega=0}$")
ax2.scatter(1-rawdata[:,4],4*rawdata[:,11],marker='*',color="green",linestyle="dashed",s=150)
ax2.plot(1-criData[:,4],4*criData[:,11],"-",color="purple",linestyle="dashed",label=r"$\mathcal{D}^{\mathbf{Q}=\mathbf{0},\Omega=0}$")
ax2.scatter(1-criData[:,4],4*criData[:,11],marker='d',color="purple",linestyle="dashed",s=150)




ax2.set_ylim([0,70])
ax2.set_ylabel(r"$\mathcal{D}^{\mathbf{Q}=\mathbf{0},\Omega=0}$",fontsize=30)
ax.set_ylabel(r"$\Lambda_{cri}$",fontsize=30)
ax2.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='major', labelsize=18)
ax.annotate(r"$AF$",xy=(0.06,0.150),fontsize=40)
ax.set_xlabel(r"$\delta$",fontsize=30)

lns = ln1+ln2
labs = [l.get_label() for l in lns]
#ax.legend(lns, labs, loc=0,fontsize=20)
#plt.ylabel(r"")
ax.set_xlim([0.02,0.28])
plt.tight_layout()
plt.savefig("../plots/pairing_plus_criscale.png",dpi=300)

# %% [markdown]
# ## Plot of the $d$ wave as function of the magnetic

# %%
alldata = np.loadtxt('../data/copy_rawdata.dat',comments = "#")
wantfill = np.unique(criData[:,4])
for fill in wantfill:
    one_fill = alldata[np.where(alldata[:,4]==fill)]
    one_fill = one_fill[one_fill[:,0].argsort()]
    plt.scatter(one_fill[:,8],one_fill[:,11])
    plt.plot(one_fill[:,8],one_fill[:,11],label=r"$n=$"+"{:2.2f}".format(fill))
    
#plt.xlim([0,300])
plt.plot()
plt.xscale("log")
plt.legend()

# %%
for fill in wantfill:
    one_fill = alldata[np.where(alldata[:,4]==fill)]
    one_fill = one_fill[one_fill[:,0].argsort()]
    plt.scatter(one_fill[:,0],one_fill[:,8])
    plt.plot(one_fill[:,0],one_fill[:,8],label=r"$n=$"+"{:2.2f}".format(fill))
plt.ylim([0,300])
plt.legend()

# %%
for fill in wantfill:
    one_fill = alldata[np.where(alldata[:,4]==fill)]
    one_fill = one_fill[one_fill[:,0].argsort()]
    plt.scatter(one_fill[:,0],one_fill[:,11])
    plt.plot(one_fill[:,0],one_fill[:,11],label=r"$n=$"+"{:2.2f}".format(fill))

plt.legend()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax2=plt.twinx()
rawdata = np.loadtxt("../data/rawdata_phasediag.dat")
ln1=ax.plot(1-rawdata[:,4],rawdata[:,0],'-',label=r"$\Lambda_{cri}$")
ax.fill_between(1-rawdata[:,4],rawdata[:,0],alpha=0.2)
ax.scatter(1-rawdata[:,4],rawdata[:,0],color="steelblue",alpha=0.7,edgecolor="black",s=70)
ax.scatter(1-criData[:,4],criData[:,0],color="orange",alpha=0.7,edgecolor="black",s=70)
ax.plot(1-criData[:,4],criData[:,0],'-',label=r"$\Lambda_{cri}$ decoup")
ax.fill_between(1-criData[:,4],criData[:,0],alpha=0.2)
ax.set_ylim([0,0.45])
ln2=ax2.plot(1-rawdata[:,4],rawdata[:,11]/rawdata[:,8],"-",color="green",linestyle="dashed",label=r"$\mathcal{D}^{\mathbf{Q}=\mathbf{0},\Omega=0}$")
ax2.scatter(1-rawdata[:,4],rawdata[:,11]/rawdata[:,8],marker='*',color="green",linestyle="dashed",s=150)
ax2.plot(1-criData[:,4],criData[:,11]/criData[:,8],"-",color="purple",linestyle="dashed",label=r"$\mathcal{D}^{\mathbf{Q}=\mathbf{0},\Omega=0}$")
ax2.scatter(1-criData[:,4],criData[:,11]/criData[:,8],marker='d',color="purple",linestyle="dashed",s=150)




#ax2.set_ylim([0,70])
ax2.set_ylabel(r"$\mathcal{D}^{\mathbf{Q}=\mathbf{0},\Omega=0}$",fontsize=30)
ax.set_ylabel(r"$\Lambda_{cri}$",fontsize=30)
ax2.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='major', labelsize=18)
ax.annotate(r"$AF$",xy=(0.06,0.150),fontsize=40)
ax.set_xlabel(r"$\delta$",fontsize=30)

lns = ln1+ln2
labs = [l.get_label() for l in lns]
#ax.legend(lns, labs, loc=0,fontsize=20)
#plt.ylabel(r"")
ax.set_xlim([0.02,0.28])
plt.tight_layout()
plt.savefig("../plots/pairing_plus_criscale.png",dpi=300)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax2=plt.twinx()
rawdata = np.loadtxt("../data/rawdata_phasediag.dat")
ln1=ax.plot(1-rawdata[:,4],rawdata[:,0],'-',label=r"$\Lambda_{cri}$")
ax.fill_between(1-rawdata[:,4],rawdata[:,0],alpha=0.2)
ax.scatter(1-rawdata[:,4],rawdata[:,0],color="steelblue",alpha=0.7,edgecolor="black",s=70)
ax.scatter(1-criData[:,4],criData[:,0],color="orange",alpha=0.7,edgecolor="black",s=70)
ln4= ax.plot(1-criData[:,4],criData[:,0],'-',label=r"$\Lambda_{cri}$ decoup")
ax.fill_between(1-criData[:,4],criData[:,0],alpha=0.2)
ax.set_ylim([0,0.45])
ln2=ax2.plot(1-rawdata[:,4],4*rawdata[:,11],"-",color="green",linestyle="dashed",label=r"$\mathcal{D}^{\mathbf{Q}=\mathbf{0},\Omega=0}$")
ax2.scatter(1-rawdata[:,4],4*rawdata[:,11],marker='*',color="green",linestyle="dashed",s=150)
ln3=ax2.plot(1-criData[:,4],4*criData[:,11],"-",color="purple",linestyle="dashed",label=r"$\mathcal{D}^{\mathbf{Q}=\mathbf{0},\Omega=0}$, decoup")
ax2.scatter(1-criData[:,4],4*criData[:,11],marker='d',color="purple",linestyle="dashed",s=150)




#ax2.set_ylim([0,70])
ax2.set_ylabel(r"$\mathcal{D}^{\mathbf{Q}=\mathbf{0},\Omega=0}$",fontsize=30)
ax.set_ylabel(r"$\Lambda_{cri}$",fontsize=30)
ax2.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='major', labelsize=18)
ax.annotate(r"$AF$",xy=(0.06,0.150),fontsize=40)
ax.set_xlabel(r"$\delta$",fontsize=30)

lns = ln1+ln2+ln4+ln3
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc=0,fontsize=20)
#plt.ylabel(r"")
ax.set_xlim([0.02,0.28])
plt.tight_layout()
plt.savefig("../plots/pairing_plus_criscale.png",dpi=300)

# %%
import h5py 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
ax = plt.subplot()
dwave_flow = np.loadtxt("/home/ciro/Documents/Talks/dwave.dat")
uhub,beta,tpri,dens = 2.,90,-0.05,0.82

fs = 18 
title = r"$T="+ "{:.3f}".format(1./beta*4.)+"t$, $U="+"%1.0f"%(4.*uhub)+"t$"
label = r"$t'="+"{:.2f}".format(tpri*4.)+"$t, $n="+"{:.3f}".format(dens)+"$"
ax.plot((dwave_flow[:,0]),4*dwave_flow[:,1],marker='o', color="blue",label=label,alpha =0.5)
ax.legend(fontsize = fs)
ax.set_title(title,fontsize =fs +2)
ax.set_xscale('log')
ax.set_xlabel(r"$\Lambda$",fontsize = fs+2)
ax.set_ylabel(r"$\mathrm{max}(\mathcal{D}^\Lambda)$",fontsize = fs+2)
ax.set_xticks([1.0, 0.5,0.2,0.1,0.05])
ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax.grid()
plt.savefig('/home/ciro/Documents/Talks/dwave_flow.png',dpi=300)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax2=plt.twinx()
rawdata = np.loadtxt("/home/ciro/Documents/Talks/rawdata_phasediag.dat")
ln1=ax.plot(1-rawdata[:,4],rawdata[:,0],'-',label=r"$\Lambda_{cri}$")
ax.fill_between(1-rawdata[:,4],rawdata[:,0],alpha=0.2)
ax.scatter(1-rawdata[:,4],rawdata[:,0],color="steelblue",alpha=0.7,edgecolor="black",s=70)
ax.set_ylim([0,0.45])
ln2=ax2.plot(1-rawdata[:,4],4*rawdata[:,11],"-",color="green",linestyle="dashed",label=r"$\mathcal{D}^{\mathbf{Q}=\mathbf{0},\Omega=0}$")
ax2.scatter(1-rawdata[:,4],4*rawdata[:,11],marker='*',color="green",linestyle="dashed",s=150)




ax2.set_ylim([0,70])
ax2.set_ylabel(r"$\mathcal{D}^{\mathbf{Q}=\mathbf{0},\Omega=0}$",fontsize=30)
ax.set_ylabel(r"$\Lambda_{cri}$",fontsize=30)
ax2.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='major', labelsize=18)
ax.annotate(r"$AF$",xy=(0.06,0.150),fontsize=40)
ax.set_xlabel(r"$\delta$",fontsize=30)

lns = ln1+ln2
labs = [l.get_label() for l in lns]
#ax.legend(lns, labs, loc=0,fontsize=20)
#plt.ylabel(r"")
ax.set_xlim([0.02,0.28])
plt.tight_layout()
plt.savefig("/home/ciro/Documents/Talks/pairing_plus_criscale.png",dpi=300)

# %%
plt.plot(1-rawdata[:,4],rawdata[:,11],"-o")
